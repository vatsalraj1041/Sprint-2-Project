# %%
import numpy as np # numerical computing 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #visualization
import seaborn as sns #modern visualization
# %matplotlib inline
file_path='C:\\Users\\thath\\Downloads\\capg ms azure training\\sprint 1 projects\\IPL Analysis\\ipldata\\'
matches = pd.read_csv(file_path+'matches.csv')
deliveries = pd.read_csv(file_path+'deliveries.csv')
matches=matches[matches['result']== 'normal']
wbr= matches[["id", "season","winner","win_by_runs"]]
wbr=wbr.set_index(['season','winner'])
wbr.reset_index(inplace=True)
wbr=wbr[wbr.win_by_runs > 0]
print(wbr.to_string())
# Out:
#      season                       winner     id  win_by_runs
# 0      2017          Sunrisers Hyderabad      1           35
# 4      2017  Royal Challengers Bangalore      5           15
# 8      2017             Delhi Daredevils      9           97
# 13     2017        Kolkata Knight Riders     14           17
# 14     2017             Delhi Daredevils     15           51
# 16     2017       Rising Pune Supergiant     17           27
# 18     2017          Sunrisers Hyderabad     19            5
# 19     2017  Royal Challengers Bangalore     20           21
# 20     2017          Sunrisers Hyderabad     21           15
# 23     2017               Mumbai Indians     24           14
# 25     2017              Kings XI Punjab     26           26
# 26     2017        Kolkata Knight Riders     27           82
# 27     2017       Rising Pune Supergiant     28            3
# 31     2017          Sunrisers Hyderabad     32           26
# ...

# %%
wbr.groupby('season').plot(x="winner",y="win_by_runs", kind="bar")
# Out:
# season
# 2008    AxesSubplot(0.125,0.125;0.775x0.755)
# 2009    AxesSubplot(0.125,0.125;0.775x0.755)
# 2010    AxesSubplot(0.125,0.125;0.775x0.755)
# 2011    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012    AxesSubplot(0.125,0.125;0.775x0.755)
# 2013    AxesSubplot(0.125,0.125;0.775x0.755)
# 2014    AxesSubplot(0.125,0.125;0.775x0.755)
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017    AxesSubplot(0.125,0.125;0.775x0.755)
# 2018    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
